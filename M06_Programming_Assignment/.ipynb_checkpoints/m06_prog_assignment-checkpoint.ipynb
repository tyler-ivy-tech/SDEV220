# %% [markdown]
# 13.1 Write the current date as a string to the text file today.txt.

# %%
from datetime import date
file = "today.txt"
with open(file, "w") as fout:
    fout.write(str(date.today()))
print("Write operation complete!")
# Out:
# Write operation complete!

# %% [markdown]
# 13.2 Read the text file today.txt into the string today_string.

# %%
with open(file, "r") as fin:
    today_string = fin.read()
print(f"Read complete.")
# Out:
# Read complete.

# %% [markdown]
# 13.3 Parse the date from today_string.

# %%
print(f"Variable today_string is set to {today_string}.")
# Out:
# Variable today_string is set to 2026-07-11.

# %% [markdown]
# 15.1 Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between zero and one, print the current time, and then exit.

# %%
from multiprocessing import Process, Pool
import os
from datetime import datetime
from time import sleep
from random import random

def print_time_process(wait_time):
    print(f"Process {os.getpid()} started.")
    sleep(wait_time)
    print(f"Process {os.getpid()}: {datetime.now()}")

if __name__ == "__main__":
    for i in range(3):
        wait_time = random()
        p = Process(target=print_time_process, args=(wait_time,))
        p.start()

    print("All processes started.")
# Out:
# All processes started.

# %% [markdown]
# NOTE: This function works in Python but not in Jupyter Notebooks. Not sure why this is. Some online searches revealed this is a known issue. If there is a way to get this to work in Jupyter Notebooks, I would love to know.
